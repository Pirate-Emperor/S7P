# %% [markdown]
# # Study of essential text pre-processing techniques. Write python script for the essential text preprocessing techniques. Store the preprocessed data into a separate column of .CSV file. Compare the outcomes with and without using libraries for the same.

# %% [markdown]
# ## Perform the following task with using inbuilt Python Libraries:

# %%
# !pip install deep_translator emoji
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Collecting emoji
#   Downloading emoji-2.14.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.9 MB/s eta 0:00:00
# Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 13.7 MB/s eta 0:00:00
# Installing collected packages: emoji, deep_translator
# Successfully installed deep_translator-1.11.4 emoji-2.14.0

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from deep_translator import GoogleTranslator
import emoji
import string
import re

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd "drive/My Drive/Sem-6/ML/P4"
# Out:
# /content/drive/My Drive/Sem-6/ML/P4

# %%
data = pd.read_csv("PTweet_WWE.csv")
data.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/WWE/status/174201779437427...
# 1  https://twitter.com/WWE/status/174573989977118...
# 2  https://twitter.com/WWE/status/174567949971749...
# 3  https://twitter.com/WWE/status/174564199274113...
# 4  https://twitter.com/WWE/status/174559668762676...
#
#                                                 text name username  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...  WWE     @WWE
# 1  Who had the best Instagram photo of the week?!...  WWE     @WWE
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...  WWE     @WWE
# 3  An All Mighty moment in the 2023 Men's #RoyalR...  WWE     @WWE
# 4                                   Outta nowhere! 😲  WWE     @WWE
#
#                           date  is_rt  n_comment  n_rt  n_quote  n_like
# 0    Jan 2, 2024 · 2:59 AM UTC  False       1088  9916     1856   49998
# 1   Jan 12, 2024 · 9:30 AM UTC  False         47    39        3     342
# 2   Jan 12, 2024 · 5:30 AM UTC  False         46    72        2     624
# 3   Jan 12, 2024 · 3:00 AM UTC  False         58   213       17    2454
# 4  Jan 12, 2024 · 12:00 AM UTC  False         70   354       10    3853

# %%
df = pd.DataFrame(data['text'])
df.head()
# Out:
#                                                 text
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲

# %% [markdown]
# ### 1. Lower Casing

# %%
# Task 1: Lowercasing
df['lowercased_text'] = df['text'].apply(lambda x: x.lower())
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲

# %% [markdown]
# ### 2. Tokenization

# %%
# Task 2: Tokenization
# df['tokens'] = df['lowercased_text'].apply(lambda x: re.findall(r'\b\w+\b', x))
df['tokens'] = df['lowercased_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text  \
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲
#
#                                               tokens
# 0  [if, ya, smell, ....., @, therock, has, come, ...
# 1  [who, had, the, best, instagram, photo, of, th...
# 2  [these, #, royalrumble, crashers, were, ruthle...
# 3  [an, all, mighty, moment, in, the, 2023, men, ...
# 4                             [outta, nowhere, !, 😲]

# %% [markdown]
# ### 3. Punctuation Mark Removal

# %%
# Task 3: Punctuation Mark Removal
df['cleaned_text'] = df['tokens'].apply(lambda x: ''.join(char for char in x if char not in string.punctuation))
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text  \
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲
#
#                                               tokens  \
# 0  [if, ya, smell, ....., @, therock, has, come, ...
# 1  [who, had, the, best, instagram, photo, of, th...
# 2  [these, #, royalrumble, crashers, were, ruthle...
# 3  [an, all, mighty, moment, in, the, 2023, men, ...
# 4                             [outta, nowhere, !, 😲]
#
#                                         cleaned_text
# 0           ifyasmell.....therockhascomebacktowweraw
# 1  whohadthebestinstagramphotooftheweekhttps//www...
# 2  theseroyalrumblecrasherswereruthlesshttps//tub...
# 3    anallmightymomentinthe2023men'sroyalrumblematch
# 4                                      outtanowhere😲

# %% [markdown]
# ### 4. Stop Word Removal

# %%
# Task 4: Stop Word Removal
stop_words = set(stopwords.words('english'))
df['filtered_text'] = df['tokens'].apply(lambda x: ' '.join(word for word in x if word not in stop_words))
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text  \
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲
#
#                                               tokens  \
# 0  [if, ya, smell, ....., @, therock, has, come, ...
# 1  [who, had, the, best, instagram, photo, of, th...
# 2  [these, #, royalrumble, crashers, were, ruthle...
# 3  [an, all, mighty, moment, in, the, 2023, men, ...
# 4                             [outta, nowhere, !, 😲]
#
#                                         cleaned_text  \
# 0           ifyasmell.....therockhascomebacktowweraw
# 1  whohadthebestinstagramphotooftheweekhttps//www...
# 2  theseroyalrumblecrasherswereruthlesshttps//tub...
# 3    anallmightymomentinthe2023men'sroyalrumblematch
# 4                                      outtanowhere😲
#
#                                        filtered_text
# 0      ya smell ..... @ therock come back # wweraw !
# 1  best instagram photo week ? ! https : //www.ww...
# 2  # royalrumble crashers ruthless ! https : //tu...
# 3    mighty moment 2023 men 's # royalrumble match !
# 4                                  outta nowhere ! 😲

# %% [markdown]
# ### 5. Stemming

# %%
# Task 5: Stemming
stemmer = PorterStemmer()
df['stemmed_Text'] = df['tokens'].apply(lambda x: ' '.join(stemmer.stem(word) for word in x))
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text  \
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲
#
#                                               tokens  \
# 0  [if, ya, smell, ....., @, therock, has, come, ...
# 1  [who, had, the, best, instagram, photo, of, th...
# 2  [these, #, royalrumble, crashers, were, ruthle...
# 3  [an, all, mighty, moment, in, the, 2023, men, ...
# 4                             [outta, nowhere, !, 😲]
#
#                                         cleaned_text  \
# 0           ifyasmell.....therockhascomebacktowweraw
# 1  whohadthebestinstagramphotooftheweekhttps//www...
# 2  theseroyalrumblecrasherswereruthlesshttps//tub...
# 3    anallmightymomentinthe2023men'sroyalrumblematch
# 4                                      outtanowhere😲
#
#                                        filtered_text  \
# 0      ya smell ..... @ therock come back # wweraw !
# 1  best instagram photo week ? ! https : //www.ww...
# 2  # royalrumble crashers ruthless ! https : //tu...
# 3    mighty moment 2023 men 's # royalrumble match !
# 4                                  outta nowhere ! 😲
#
#                                         stemmed_Text
# 0  if ya smell ..... @ therock ha come back to # ...
# 1  who had the best instagram photo of the week ?...
# 2  these # royalrumbl crasher were ruthless ! htt...
# 3  an all mighti moment in the 2023 men 's # roya...
# 4                                   outta nowher ! 😲

# %% [markdown]
# ### 6. Lemmatization

# %%
# Task 6: Lemmatization
lemmatizer = WordNetLemmatizer()
df['lemmatized_text'] = df['tokens'].apply(lambda x: ' '.join(lemmatizer.lemmatize(word) for word in x))
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text  \
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲
#
#                                               tokens  \
# 0  [if, ya, smell, ....., @, therock, has, come, ...
# 1  [who, had, the, best, instagram, photo, of, th...
# 2  [these, #, royalrumble, crashers, were, ruthle...
# 3  [an, all, mighty, moment, in, the, 2023, men, ...
# 4                             [outta, nowhere, !, 😲]
#
#                                         cleaned_text  \
# 0           ifyasmell.....therockhascomebacktowweraw
# 1  whohadthebestinstagramphotooftheweekhttps//www...
# 2  theseroyalrumblecrasherswereruthlesshttps//tub...
# 3    anallmightymomentinthe2023men'sroyalrumblematch
# 4                                      outtanowhere😲
#
#                                        filtered_text  \
# 0      ya smell ..... @ therock come back # wweraw !
# 1  best instagram photo week ? ! https : //www.ww...
# 2  # royalrumble crashers ruthless ! https : //tu...
# 3    mighty moment 2023 men 's # royalrumble match !
# 4                                  outta nowhere ! 😲
#
#                                         stemmed_Text  \
# 0  if ya smell ..... @ therock ha come back to # ...
# 1  who had the best instagram photo of the week ?...
# 2  these # royalrumbl crasher were ruthless ! htt...
# 3  an all mighti moment in the 2023 men 's # roya...
# 4                                   outta nowher ! 😲
#
#                                      lemmatized_text
# 0  if ya smell ..... @ therock ha come back to # ...
# 1  who had the best instagram photo of the week ?...
# 2  these # royalrumble crasher were ruthless ! ht...
# 3  an all mighty moment in the 2023 men 's # roya...
# 4                                  outta nowhere ! 😲

# %%
for index, row in df.iterrows():
  for token in row['tokens']:
    lemmatized_word = lemmatizer.lemmatize(token)
    print(f"Token: {token}, Lemmatized: {lemmatized_word}, Equal: {token == lemmatized_word}")
# Out:
# Token: if, Lemmatized: if, Equal: True
# Token: ya, Lemmatized: ya, Equal: True
# Token: smell, Lemmatized: smell, Equal: True
# Token: ....., Lemmatized: ....., Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: therock, Lemmatized: therock, Equal: True
# Token: has, Lemmatized: ha, Equal: False
# Token: come, Lemmatized: come, Equal: True
# Token: back, Lemmatized: back, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wweraw, Lemmatized: wweraw, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: who, Lemmatized: who, Equal: True
# Token: had, Lemmatized: had, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: best, Lemmatized: best, Equal: True
# Token: instagram, Lemmatized: instagram, Equal: True
# Token: photo, Lemmatized: photo, Equal: True
# Token: of, Lemmatized: of, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: week, Lemmatized: week, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //www.wwe.com/gallery/the-25-best-instagram-photos-of-the-week-january-7-2024, Lemmatized: //www.wwe.com/gallery/the-25-best-instagram-photos-of-the-week-january-7-2024, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: fid-40650941, Lemmatized: fid-40650941, Equal: True
# Token: these, Lemmatized: these, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: royalrumble, Lemmatized: royalrumble, Equal: True
# Token: crashers, Lemmatized: crasher, Equal: False
# Token: were, Lemmatized: were, Equal: True
# Token: ruthless, Lemmatized: ruthless, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //tube.mint.lgbt/vv5fxhfxce4, Lemmatized: //tube.mint.lgbt/vv5fxhfxce4, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: si=nazclwedrvrerise, Lemmatized: si=nazclwedrvrerise, Equal: True
# Token: an, Lemmatized: an, Equal: True
# Token: all, Lemmatized: all, Equal: True
# Token: mighty, Lemmatized: mighty, Equal: True
# Token: moment, Lemmatized: moment, Equal: True
# Token: in, Lemmatized: in, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: 2023, Lemmatized: 2023, Equal: True
# Token: men, Lemmatized: men, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: royalrumble, Lemmatized: royalrumble, Equal: True
# Token: match, Lemmatized: match, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: outta, Lemmatized: outta, Equal: True
# Token: nowhere, Lemmatized: nowhere, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: 😲, Lemmatized: 😲, Equal: True
# Token: thanks, Lemmatized: thanks, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: stopping, Lemmatized: stopping, Equal: True
# Token: by, Lemmatized: by, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: performance, Lemmatized: performance, Equal: True
# Token: center, Lemmatized: center, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: dkelce1, Lemmatized: dkelce1, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: tribal, Lemmatized: tribal, Equal: True
# Token: chief, Lemmatized: chief, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: unfazed, Lemmatized: unfazed, Equal: True
# Token: 🤣, Lemmatized: 🤣, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: wweromanreigns, Lemmatized: wweromanreigns, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: heymanhustle, Lemmatized: heymanhustle, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: was, Lemmatized: wa, Equal: False
# Token: great, Lemmatized: great, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: have, Lemmatized: have, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: dkelce1, Lemmatized: dkelce1, Equal: True
# Token: come, Lemmatized: come, Equal: True
# Token: out, Lemmatized: out, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: visit, Lemmatized: visit, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: performance, Lemmatized: performance, Equal: True
# Token: center, Lemmatized: center, Equal: True
# Token: today, Lemmatized: today, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: attention, Lemmatized: attention, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: nhlflyers, Lemmatized: nhlflyers, Equal: True
# Token: fans, Lemmatized: fan, Equal: False
# Token: !, Lemmatized: !, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: grittynhl, Lemmatized: grittynhl, Equal: True
# Token: has, Lemmatized: ha, Equal: False
# Token: the, Lemmatized: the, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwegoldentitle, Lemmatized: wwegoldentitle, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: message, Lemmatized: message, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: snoopdogg, Lemmatized: snoopdogg, Equal: True
# Token: ahead, Lemmatized: ahead, Equal: True
# Token: of, Lemmatized: of, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wrestlemania, Lemmatized: wrestlemania, Equal: True
# Token: in, Lemmatized: in, Equal: True
# Token: philly, Lemmatized: philly, Equal: True
# Token: 👀, Lemmatized: 👀, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: dustyclassic, Lemmatized: dustyclassic, Equal: True
# Token: continues, Lemmatized: continues, Equal: True
# Token: next, Lemmatized: next, Equal: True
# Token: week, Lemmatized: week, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: with, Lemmatized: with, Equal: True
# Token: these, Lemmatized: these, Equal: True
# Token: two, Lemmatized: two, Equal: True
# Token: massive, Lemmatized: massive, Equal: True
# Token: matchups, Lemmatized: matchup, Equal: False
# Token: !, Lemmatized: !, Equal: True
# Token: who, Lemmatized: who, Equal: True
# Token: do, Lemmatized: do, Equal: True
# Token: you, Lemmatized: you, Equal: True
# Token: have, Lemmatized: have, Equal: True
# Token: advancing, Lemmatized: advancing, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: semi-finals, Lemmatized: semi-finals, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: 🏆, Lemmatized: 🏆, Equal: True
# Token: 📺, Lemmatized: 📺, Equal: True
# Token: 8/7c, Lemmatized: 8/7c, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: usanetwork, Lemmatized: usanetwork, Equal: True
# Token: available, Lemmatized: available, Equal: True
# Token: now, Lemmatized: now, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: wweshop, Lemmatized: wweshop, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: get, Lemmatized: get, Equal: True
# Token: these, Lemmatized: these, Equal: True
# Token: all-new, Lemmatized: all-new, Equal: True
# Token: shirts, Lemmatized: shirt, Equal: False
# Token: featuring, Lemmatized: featuring, Equal: True
# Token: r-truth, Lemmatized: r-truth, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: rest, Lemmatized: rest, Equal: True
# Token: of, Lemmatized: of, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: judgment, Lemmatized: judgment, Equal: True
# Token: day, Lemmatized: day, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: 😈, Lemmatized: 😈, Equal: True
# Token: 🛒, Lemmatized: 🛒, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //bit.ly/47q2pqn, Lemmatized: //bit.ly/47q2pqn, Equal: True
# Token: take, Lemmatized: take, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: look, Lemmatized: look, Equal: True
# Token: at, Lemmatized: at, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: tiffstrattonwwe, Lemmatized: tiffstrattonwwe, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: eventful, Lemmatized: eventful, Equal: True
# Token: day, Lemmatized: day, Equal: True
# Token: as, Lemmatized: a, Equal: False
# Token: @, Lemmatized: @, Equal: True
# Token: fallonhenleywwe, Lemmatized: fallonhenleywwe, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: ranch, Lemmatized: ranch, Equal: True
# Token: hand, Lemmatized: hand, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: enjoy, Lemmatized: enjoy, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: cold, Lemmatized: cold, Equal: True
# Token: one, Lemmatized: one, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: nationalmilkday, Lemmatized: nationalmilkday, Equal: True
# Token: just, Lemmatized: just, Equal: True
# Token: like, Lemmatized: like, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: therock, Lemmatized: therock, Equal: True
# Token: &, Lemmatized: &, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: realkurtangle, Lemmatized: realkurtangle, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: happy, Lemmatized: happy, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: nationalmilkday, Lemmatized: nationalmilkday, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: can, Lemmatized: can, Equal: True
# Token: big, Lemmatized: big, Equal: True
# Token: body, Lemmatized: body, Equal: True
# Token: javi, Lemmatized: javi, Equal: True
# Token: upset, Lemmatized: upset, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: joegacy, Lemmatized: joegacy, Equal: True
# Token: tomorrow, Lemmatized: tomorrow, Equal: True
# Token: night, Lemmatized: night, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: nxtlevelup, Lemmatized: nxtlevelup, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //www.wwe.com/shows/nxt-level-up/nxt-level-up-jan-12-2024, Lemmatized: //www.wwe.com/shows/nxt-level-up/nxt-level-up-jan-12-2024, Equal: True
# Token: thanks, Lemmatized: thanks, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: joining, Lemmatized: joining, Equal: True
# Token: us, Lemmatized: u, Equal: False
# Token: on, Lemmatized: on, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwethebump, Lemmatized: wwethebump, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: miayim, Lemmatized: miayim, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: 2024, Lemmatized: 2024, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: shaping, Lemmatized: shaping, Equal: True
# Token: up, Lemmatized: up, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: be, Lemmatized: be, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: big, Lemmatized: big, Equal: True
# Token: year, Lemmatized: year, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: you, Lemmatized: you, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: we, Lemmatized: we, Equal: True
# Token: hope, Lemmatized: hope, Equal: True
# Token: you, Lemmatized: you, Equal: True
# Token: 'll, Lemmatized: 'll, Equal: True
# Token: join, Lemmatized: join, Equal: True
# Token: us, Lemmatized: u, Equal: False
# Token: again, Lemmatized: again, Equal: True
# Token: soon, Lemmatized: soon, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: 🔥🔥🔥, Lemmatized: 🔥🔥🔥, Equal: True
# Token: live, Lemmatized: live, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: laugh, Lemmatized: laugh, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: love, Lemmatized: love, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: r-truth, Lemmatized: r-truth, Equal: True
# Token: &, Lemmatized: &, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: judgment, Lemmatized: judgment, Equal: True
# Token: day, Lemmatized: day, Equal: True
# Token: have, Lemmatized: have, Equal: True
# Token: 2, Lemmatized: 2, Equal: True
# Token: new, Lemmatized: new, Equal: True
# Token: tees, Lemmatized: tee, Equal: False
# Token: available, Lemmatized: available, Equal: True
# Token: at, Lemmatized: at, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wweshop, Lemmatized: wweshop, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: 🛒, Lemmatized: 🛒, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //bit.ly/47q2pqn, Lemmatized: //bit.ly/47q2pqn, Equal: True
# Token: they, Lemmatized: they, Equal: True
# Token: were, Lemmatized: were, Equal: True
# Token: n't, Lemmatized: n't, Equal: True
# Token: supposed, Lemmatized: supposed, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: be, Lemmatized: be, Equal: True
# Token: in, Lemmatized: in, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: royalrumble, Lemmatized: royalrumble, Equal: True
# Token: match, Lemmatized: match, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: what, Lemmatized: what, Equal: True
# Token: happens, Lemmatized: happens, Equal: True
# Token: when, Lemmatized: when, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: superstars, Lemmatized: superstar, Equal: False
# Token: interfere, Lemmatized: interfere, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: even, Lemmatized: even, Equal: True
# Token: steal, Lemmatized: steal, Equal: True
# Token: entries, Lemmatized: entry, Equal: False
# Token: ?, Lemmatized: ?, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: find, Lemmatized: find, Equal: True
# Token: out, Lemmatized: out, Equal: True
# Token: now, Lemmatized: now, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //tube.mint.lgbt/vv5fxhfxce4, Lemmatized: //tube.mint.lgbt/vv5fxhfxce4, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: si=erqiyu2q4qjyjsnb, Lemmatized: si=erqiyu2q4qjyjsnb, Equal: True
# Token: 👀, Lemmatized: 👀, Equal: True
# Token: message, Lemmatized: message, Equal: True
# Token: sent, Lemmatized: sent, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: smackdown, Lemmatized: smackdown, Equal: True
# Token: icymi, Lemmatized: icymi, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: watch, Lemmatized: watch, Equal: True
# Token: r-truth, Lemmatized: r-truth, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: lovely, Lemmatized: lovely, Equal: True
# Token: tribute, Lemmatized: tribute, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: judgment, Lemmatized: judgment, Equal: True
# Token: day, Lemmatized: day, Equal: True
# Token: -, Lemmatized: -, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //tube.mint.lgbt/ptodbw_bhiu, Lemmatized: //tube.mint.lgbt/ptodbw_bhiu, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: si=bp4e_klnwi7-1rv7, Lemmatized: si=bp4e_klnwi7-1rv7, Equal: True
# Token: now, Lemmatized: now, Equal: True
# Token: that, Lemmatized: that, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: what, Lemmatized: what, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: up, Lemmatized: up, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: say, Lemmatized: say, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: my, Lemmatized: my, Equal: True
# Token: chest, Lemmatized: chest, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: judgment, Lemmatized: judgment, Equal: True
# Token: day, Lemmatized: day, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: awesome, Lemmatized: awesome, Equal: True
# Token: truth, Lemmatized: truth, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: diy, Lemmatized: diy, Equal: True
# Token: ..., Lemmatized: ..., Equal: True
# Token: oh, Lemmatized: oh, Equal: True
# Token: my, Lemmatized: my, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: this, Lemmatized: this, Equal: True
# Token: monday, Lemmatized: monday, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wweraw, Lemmatized: wweraw, Equal: True
# Token: 8/7c, Lemmatized: 8/7c, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: usanetwork, Lemmatized: usanetwork, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: road, Lemmatized: road, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: vengeanceday, Lemmatized: vengeanceday, Equal: True
# Token: got, Lemmatized: got, Equal: True
# Token: started, Lemmatized: started, Equal: True
# Token: in, Lemmatized: in, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: big, Lemmatized: big, Equal: True
# Token: way, Lemmatized: way, Equal: True
# Token: last, Lemmatized: last, Equal: True
# Token: night, Lemmatized: night, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: but, Lemmatized: but, Equal: True
# Token: who, Lemmatized: who, Equal: True
# Token: claimed, Lemmatized: claimed, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: top, Lemmatized: top, Equal: True
# Token: spot, Lemmatized: spot, Equal: True
# Token: in, Lemmatized: in, Equal: True
# Token: this, Lemmatized: this, Equal: True
# Token: week, Lemmatized: week, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwetop10, Lemmatized: wwetop10, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: watch, Lemmatized: watch, Equal: True
# Token: here, Lemmatized: here, Equal: True
# Token: 👉, Lemmatized: 👉, Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //tube.mint.lgbt/watch, Lemmatized: //tube.mint.lgbt/watch, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: v=s59qmcdnyzm, Lemmatized: v=s59qmcdnyzm, Equal: True
# Token: intercontinental, Lemmatized: intercontinental, Equal: True
# Token: champion, Lemmatized: champion, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: gunther_aut, Lemmatized: gunther_aut, Equal: True
# Token: returns, Lemmatized: return, Equal: False
# Token: to, Lemmatized: to, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wweraw, Lemmatized: wweraw, Equal: True
# Token: this, Lemmatized: this, Equal: True
# Token: monday, Lemmatized: monday, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: next, Lemmatized: next, Equal: True
# Token: week, Lemmatized: week, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: 🤔, Lemmatized: 🤔, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: battle, Lemmatized: battle, Equal: True
# Token: royal, Lemmatized: royal, Equal: True
# Token: with, Lemmatized: with, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: twist, Lemmatized: twist, Equal: True
# Token: will, Lemmatized: will, Equal: True
# Token: determine, Lemmatized: determine, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: real_valkyria, Lemmatized: real_valkyria, Equal: True
# Token: 's, Lemmatized: 's, Equal: True
# Token: next, Lemmatized: next, Equal: True
# Token: challenger, Lemmatized: challenger, Equal: True
# Token: 🏆, Lemmatized: 🏆, Equal: True
# Token: two, Lemmatized: two, Equal: True
# Token: massive, Lemmatized: massive, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: dustyclassic, Lemmatized: dustyclassic, Equal: True
# Token: matchups, Lemmatized: matchup, Equal: False
# Token: 👊, Lemmatized: 👊, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: tatumpaxley, Lemmatized: tatumpaxley, Equal: True
# Token: &, Lemmatized: &, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: real_valkyria, Lemmatized: real_valkyria, Equal: True
# Token: battle, Lemmatized: battle, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: elektralopezwwe, Lemmatized: elektralopezwwe, Equal: True
# Token: &, Lemmatized: &, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: lolavicewwe, Lemmatized: lolavicewwe, Equal: True
# Token: 📺, Lemmatized: 📺, Equal: True
# Token: 8/7c, Lemmatized: 8/7c, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: usanetwork, Lemmatized: usanetwork, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: &, Lemmatized: &, Equal: True
# Token: e, Lemmatized: e, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: back, Lemmatized: back, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: beginning, Lemmatized: beginning, Equal: True
# Token: sunday, Lemmatized: sunday, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: feb., Lemmatized: feb., Equal: True
# Token: 25, Lemmatized: 25, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: aetv, Lemmatized: aetv, Equal: True
# Token: present, Lemmatized: present, Equal: True
# Token: new, Lemmatized: new, Equal: True
# Token: seasons, Lemmatized: season, Equal: False
# Token: of, Lemmatized: of, Equal: True
# Token: “, Lemmatized: “, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: rivals, Lemmatized: rival, Equal: False
# Token: ”, Lemmatized: ”, Equal: True
# Token: at, Lemmatized: at, Equal: True
# Token: 8, Lemmatized: 8, Equal: True
# Token: et/pt, Lemmatized: et/pt, Equal: True
# Token: followed, Lemmatized: followed, Equal: True
# Token: by, Lemmatized: by, Equal: True
# Token: “, Lemmatized: “, Equal: True
# Token: biography, Lemmatized: biography, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: legends, Lemmatized: legend, Equal: False
# Token: ”, Lemmatized: ”, Equal: True
# Token: at, Lemmatized: at, Equal: True
# Token: 9, Lemmatized: 9, Equal: True
# Token: et/pt, Lemmatized: et/pt, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: https, Lemmatized: http, Equal: False
# Token: :, Lemmatized: :, Equal: True
# Token: //www.wwe.com/article/wwe-on-ae-returns-sunday-feb-25, Lemmatized: //www.wwe.com/article/wwe-on-ae-returns-sunday-feb-25, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: superstar, Lemmatized: superstar, Equal: True
# Token: sunday, Lemmatized: sunday, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: aetv, Lemmatized: aetv, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: officially, Lemmatized: officially, Equal: True
# Token: back, Lemmatized: back, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: relive, Lemmatized: relive, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: epic, Lemmatized: epic, Equal: True
# Token: rivalries, Lemmatized: rivalry, Equal: False
# Token: and, Lemmatized: and, Equal: True
# Token: careers, Lemmatized: career, Equal: False
# Token: of, Lemmatized: of, Equal: True
# Token: top, Lemmatized: top, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: legends, Lemmatized: legend, Equal: False
# Token: with, Lemmatized: with, Equal: True
# Token: knock-out, Lemmatized: knock-out, Equal: True
# Token: seasons, Lemmatized: season, Equal: False
# Token: of, Lemmatized: of, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: rivals, Lemmatized: rival, Equal: False
# Token: &, Lemmatized: &, Equal: True
# Token: biography, Lemmatized: biography, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: legends, Lemmatized: legend, Equal: False
# Token: starting, Lemmatized: starting, Equal: True
# Token: sunday, Lemmatized: sunday, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: february, Lemmatized: february, Equal: True
# Token: 25, Lemmatized: 25, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: ms.spr.ly/6010im44j, Lemmatized: ms.spr.ly/6010im44j, Equal: True
# Token: step, Lemmatized: step, Equal: True
# Token: back, Lemmatized: back, Equal: True
# Token: into, Lemmatized: into, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: ring, Lemmatized: ring, Equal: True
# Token: with, Lemmatized: with, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: superstar, Lemmatized: superstar, Equal: True
# Token: sunday, Lemmatized: sunday, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: all-new, Lemmatized: all-new, Equal: True
# Token: episodes, Lemmatized: episode, Equal: False
# Token: of, Lemmatized: of, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: rivals, Lemmatized: rival, Equal: False
# Token: &, Lemmatized: &, Equal: True
# Token: biography, Lemmatized: biography, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: legends, Lemmatized: legend, Equal: False
# Token: start, Lemmatized: start, Equal: True
# Token: february, Lemmatized: february, Equal: True
# Token: 25th, Lemmatized: 25th, Equal: True
# Token: at, Lemmatized: at, Equal: True
# Token: 8/7c, Lemmatized: 8/7c, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: only, Lemmatized: only, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: aetv, Lemmatized: aetv, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wweonae, Lemmatized: wweonae, Equal: True
# Token: can, Lemmatized: can, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: dmcintyrewwe, Lemmatized: dmcintyrewwe, Equal: True
# Token: become, Lemmatized: become, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: 2-time, Lemmatized: 2-time, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: royalrumble, Lemmatized: royalrumble, Equal: True
# Token: match, Lemmatized: match, Equal: True
# Token: winner, Lemmatized: winner, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: 📍tampa, Lemmatized: 📍tampa, Equal: True
# Token: bay, Lemmatized: bay, Equal: True
# Token: 🎟️, Lemmatized: 🎟️, Equal: True
# Token: tickets, Lemmatized: ticket, Equal: False
# Token: on, Lemmatized: on, Equal: True
# Token: sale, Lemmatized: sale, Equal: True
# Token: now, Lemmatized: now, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: royalrumble.com, Lemmatized: royalrumble.com, Equal: True
# Token: can, Lemmatized: can, Equal: True
# Token: someone, Lemmatized: someone, Equal: True
# Token: please, Lemmatized: please, Equal: True
# Token: change, Lemmatized: change, Equal: True
# Token: my, Lemmatized: my, Equal: True
# Token: diaper, Lemmatized: diaper, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: how, Lemmatized: how, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: started, Lemmatized: started, Equal: True
# Token: ➡️, Lemmatized: ➡️, Equal: True
# Token: how, Lemmatized: how, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: ended, Lemmatized: ended, Equal: True
# Token: oba, Lemmatized: oba, Equal: True
# Token: femi, Lemmatized: femi, Equal: True
# Token: has, Lemmatized: ha, Equal: False
# Token: arrived, Lemmatized: arrived, Equal: True
# Token: 👊, Lemmatized: 👊, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: today, Lemmatized: today, Equal: True
# Token: at, Lemmatized: at, Equal: True
# Token: 1pm, Lemmatized: 1pm, Equal: True
# Token: et, Lemmatized: et, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: 🔥, Lemmatized: 🔥, Equal: True
# Token: no, Lemmatized: no, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: 1, Lemmatized: 1, Equal: True
# Token: contender, Lemmatized: contender, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: world, Lemmatized: world, Equal: True
# Token: heavyweight, Lemmatized: heavyweight, Equal: True
# Token: championship, Lemmatized: championship, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: jindermahal, Lemmatized: jindermahal, Equal: True
# Token: 💥, Lemmatized: 💥, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: o.c., Lemmatized: o.c., Equal: True
# Token: ’, Lemmatized: ’, Equal: True
# Token: s, Lemmatized: s, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: miayim, Lemmatized: miayim, Equal: True
# Token: 👊, Lemmatized: 👊, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: smackdown, Lemmatized: smackdown, Equal: True
# Token: gm, Lemmatized: gm, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: realnickaldis, Lemmatized: realnickaldis, Equal: True
# Token: don, Lemmatized: don, Equal: True
# Token: ’, Lemmatized: ’, Equal: True
# Token: t, Lemmatized: t, Equal: True
# Token: miss, Lemmatized: miss, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwethebump, Lemmatized: wwethebump, Equal: True
# Token: lincoln, Lemmatized: lincoln, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: ne, Lemmatized: ne, Equal: True
# Token: this, Lemmatized: this, Equal: True
# Token: friday❗️, Lemmatized: friday❗️, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: today, Lemmatized: today, Equal: True
# Token: at, Lemmatized: at, Equal: True
# Token: 1pm, Lemmatized: 1pm, Equal: True
# Token: et, Lemmatized: et, Equal: True
# Token: ;, Lemmatized: ;, Equal: True
# Token: reply, Lemmatized: reply, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: tweet, Lemmatized: tweet, Equal: True
# Token: below, Lemmatized: below, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: i, Lemmatized: i, Equal: True
# Token: may, Lemmatized: may, Equal: True
# Token: answer, Lemmatized: answer, Equal: True
# Token: your, Lemmatized: your, Equal: True
# Token: question, Lemmatized: question, Equal: True
# Token: live, Lemmatized: live, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: program, Lemmatized: program, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: wwethebump, Lemmatized: wwethebump, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: smackdown, Lemmatized: smackdown, Equal: True
# Token: happy, Lemmatized: happy, Equal: True
# Token: birthday, Lemmatized: birthday, Equal: True
# Token: to, Lemmatized: to, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: taminasnuka, Lemmatized: taminasnuka, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: what, Lemmatized: what, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: 2023, Lemmatized: 2023, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: wwe, Lemmatized: wwe, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: exclusive, Lemmatized: exclusive, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: new, Lemmatized: new, Equal: True
# Token: nxt, Lemmatized: nxt, Equal: True
# Token: north, Lemmatized: north, Equal: True
# Token: american, Lemmatized: american, Equal: True
# Token: champion, Lemmatized: champion, Equal: True
# Token: oba, Lemmatized: oba, Equal: True
# Token: femi, Lemmatized: femi, Equal: True
# Token: puts, Lemmatized: put, Equal: False
# Token: the, Lemmatized: the, Equal: True
# Token: entire, Lemmatized: entire, Equal: True
# Token: locker, Lemmatized: locker, Equal: True
# Token: room, Lemmatized: room, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: notice, Lemmatized: notice, Equal: True
# Token: after, Lemmatized: after, Equal: True
# Token: cashing, Lemmatized: cashing, Equal: True
# Token: in, Lemmatized: in, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: exclusive, Lemmatized: exclusive, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: tonydangelowwe, Lemmatized: tonydangelowwe, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: stacks_wwe, Lemmatized: stacks_wwe, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: and, Lemmatized: and, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: adrianarizzowwe, Lemmatized: adrianarizzowwe, Equal: True
# Token: are, Lemmatized: are, Equal: True
# Token: ready, Lemmatized: ready, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: celebratory, Lemmatized: celebratory, Equal: True
# Token: dinner, Lemmatized: dinner, Equal: True
# Token: with, Lemmatized: with, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: thefamily, Lemmatized: thefamily, Equal: True
# Token: after, Lemmatized: after, Equal: True
# Token: retaining, Lemmatized: retaining, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: nxttagtitles, Lemmatized: nxttagtitles, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: exclusive, Lemmatized: exclusive, Equal: True
# Token: :, Lemmatized: :, Equal: True
# Token: even, Lemmatized: even, Equal: True
# Token: though, Lemmatized: though, Equal: True
# Token: she, Lemmatized: she, Equal: True
# Token: may, Lemmatized: may, Equal: True
# Token: have, Lemmatized: have, Equal: True
# Token: come, Lemmatized: come, Equal: True
# Token: up, Lemmatized: up, Equal: True
# Token: short, Lemmatized: short, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: gigidolin_wwe, Lemmatized: gigidolin_wwe, Equal: True
# Token: knows, Lemmatized: know, Equal: False
# Token: that, Lemmatized: that, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: corajadewwe, Lemmatized: corajadewwe, Equal: True
# Token: will, Lemmatized: will, Equal: True
# Token: be, Lemmatized: be, Equal: True
# Token: feeling, Lemmatized: feeling, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: effects, Lemmatized: effect, Equal: False
# Token: of, Lemmatized: of, Equal: True
# Token: their, Lemmatized: their, Equal: True
# Token: match, Lemmatized: match, Equal: True
# Token: for, Lemmatized: for, Equal: True
# Token: quite, Lemmatized: quite, Equal: True
# Token: some, Lemmatized: some, Equal: True
# Token: time, Lemmatized: time, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: era, Lemmatized: era, Equal: True
# Token: of, Lemmatized: of, Equal: True
# Token: oba, Lemmatized: oba, Equal: True
# Token: femi, Lemmatized: femi, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: upon, Lemmatized: upon, Equal: True
# Token: us, Lemmatized: u, Equal: False
# Token: 🙌, Lemmatized: 🙌, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: how, Lemmatized: how, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: started, Lemmatized: started, Equal: True
# Token: vs, Lemmatized: v, Equal: False
# Token: how, Lemmatized: how, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: ended, Lemmatized: ended, Equal: True
# Token: .., Lemmatized: .., Equal: True
# Token: 🫠, Lemmatized: 🫠, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: game, Lemmatized: game, Equal: True
# Token: has, Lemmatized: ha, Equal: False
# Token: changed, Lemmatized: changed, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: oba, Lemmatized: oba, Equal: True
# Token: femi, Lemmatized: femi, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: new, Lemmatized: new, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: north, Lemmatized: north, Equal: True
# Token: american, Lemmatized: american, Equal: True
# Token: champion, Lemmatized: champion, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: future, Lemmatized: future, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: now, Lemmatized: now, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: oba, Lemmatized: oba, Equal: True
# Token: femi, Lemmatized: femi, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: your, Lemmatized: your, Equal: True
# Token: new, Lemmatized: new, Equal: True
# Token: north, Lemmatized: north, Equal: True
# Token: american, Lemmatized: american, Equal: True
# Token: champion, Lemmatized: champion, Equal: True
# Token: 😱, Lemmatized: 😱, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: never, Lemmatized: never, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: doubt, Lemmatized: doubt, Equal: True
# Token: ., Lemmatized: ., Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: dragonlee95, Lemmatized: dragonlee95, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: still, Lemmatized: still, Equal: True
# Token: your, Lemmatized: your, Equal: True
# Token: north, Lemmatized: north, Equal: True
# Token: american, Lemmatized: american, Equal: True
# Token: champion, Lemmatized: champion, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: wait, Lemmatized: wait, Equal: True
# Token: a, Lemmatized: a, Equal: True
# Token: minute, Lemmatized: minute, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: oba, Lemmatized: oba, Equal: True
# Token: femi, Lemmatized: femi, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: cashing, Lemmatized: cashing, Equal: True
# Token: in, Lemmatized: in, Equal: True
# Token: his, Lemmatized: his, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: nxtbreakout, Lemmatized: nxtbreakout, Equal: True
# Token: contract, Lemmatized: contract, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: this, Lemmatized: this, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: awesome, Lemmatized: awesome, Equal: True
# Token: 👏👏👏, Lemmatized: 👏👏👏, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: got, Lemmatized: got, Equal: True
# Token: ta, Lemmatized: ta, Equal: True
# Token: keep, Lemmatized: keep, Equal: True
# Token: your, Lemmatized: your, Equal: True
# Token: eyes, Lemmatized: eye, Equal: False
# Token: on, Lemmatized: on, Equal: True
# Token: the, Lemmatized: the, Equal: True
# Token: prize, Lemmatized: prize, Equal: True
# Token: ,, Lemmatized: ,, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: lexiskingwwe, Lemmatized: lexiskingwwe, Equal: True
# Token: 👀, Lemmatized: 👀, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: dragonlee95, Lemmatized: dragonlee95, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: who, Lemmatized: who, Equal: True
# Token: leaves, Lemmatized: leaf, Equal: False
# Token: as, Lemmatized: a, Equal: False
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: north, Lemmatized: north, Equal: True
# Token: american, Lemmatized: american, Equal: True
# Token: champion, Lemmatized: champion, Equal: True
# Token: ?, Lemmatized: ?, Equal: True
# Token: it, Lemmatized: it, Equal: True
# Token: is, Lemmatized: is, Equal: True
# Token: time, Lemmatized: time, Equal: True
# Token: !, Lemmatized: !, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: dragonlee95, Lemmatized: dragonlee95, Equal: True
# Token: defends, Lemmatized: defends, Equal: True
# Token: his, Lemmatized: his, Equal: True
# Token: north, Lemmatized: north, Equal: True
# Token: american, Lemmatized: american, Equal: True
# Token: championship, Lemmatized: championship, Equal: True
# Token: against, Lemmatized: against, Equal: True
# Token: @, Lemmatized: @, Equal: True
# Token: lexiskingwwe, Lemmatized: lexiskingwwe, Equal: True
# Token: next, Lemmatized: next, Equal: True
# Token: on, Lemmatized: on, Equal: True
# Token: #, Lemmatized: #, Equal: True
# Token: wwenxt, Lemmatized: wwenxt, Equal: True
# Token: !, Lemmatized: !, Equal: True

# %%
equal_counts = []
unequal_counts = []

for index, row in df.iterrows():
  equal_count = 0
  unequal_count = 0
  for token in row['tokens']:
    lemmatized_word = lemmatizer.lemmatize(token)
    if token == lemmatized_word:
      equal_count += 1
    else:
      unequal_count += 1
  equal_counts.append(equal_count)
  unequal_counts.append(unequal_count)

df['simple_count'] = equal_counts
df['complex_count'] = unequal_counts

df.head(40)
# Out:
#                                                  text  \
# 0   IF YA SMELL.....  @TheRock has come back to #W...
# 1   Who had the best Instagram photo of the week?!...
# 2   These #RoyalRumble crashers were RUTHLESS!  ht...
# 3   An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                    Outta nowhere! 😲
# 5   Thanks for stopping by the WWE Performance Cen...
# 6   The Tribal Chief is unfazed 🤣  @WWERomanReigns...
# 7   It was great to have @dkelce1 come out and vis...
# 8   Attention @NHLFlyers fans!  @GrittyNHL has the...
# 9   The #DustyClassic continues NEXT WEEK on #WWEN...
# 10  Available NOW on @WWEShop!  Get these all-new ...
# 11  Take a look at @tiffstrattonwwe's eventful day...
# 12  Enjoy a cold one on #NationalMilkDay just like...
# 13                            Happy #NationalMilkDay!
# 14  Can Big Body Javi upset @JoeGacy tomorrow nigh...
# 15  Thanks for joining us on #WWETheBump, @MiaYim!...
# 16  Live, Laugh, Love! R-Truth & The Judgment Day ...
# 17  They weren't supposed to be in the #RoyalRumbl...
# 18                                                  👀
# 19                          Message sent.  #SmackDown
# 20  ICYMI:   Watch R-Truth's lovely tribute to The...
# 21                                 Say it to my chest
# 22  The Judgment Day, The Awesome Truth and #DIY ....
# 23  The Road to #VengeanceDay got started in a BIG...
# 24  Intercontinental Champion @Gunther_AUT returns...
# 25  NEXT WEEK on #WWENXT   🤔 A Battle Royal with a...
# 26  WWE on A&E is back!  Beginning Sunday, Feb. 25...
# 27  WWE Superstar Sunday on @AETV is officially ba...
# 28  Step back into the ring with @WWE Superstar Su...
# 29  Can @DMcIntyreWWE become a 2-time #RoyalRumble...
# 30               Can someone please change my diaper?
# 31  How it started ➡️ How it ended  Oba Femi has a...
# 32  TODAY at 1pm ET:  🔥 No. 1 Contender for the WW...
# 33                    Lincoln, NE this Friday❗️  @WWE
# 34  Today at 1pm ET; reply to the tweet below and ...
# 35                    Happy birthday to @TaminaSnuka!
# 36                               What a 2023 for WWE!
# 37  EXCLUSIVE: New NXT North American Champion Oba...
# 38  EXCLUSIVE: @TonyDangeloWWE, @Stacks_WWE, and @...
# 39  EXCLUSIVE: Even though she may have come up sh...
#
#                                       lowercased_text  \
# 0   if ya smell.....  @therock has come back to #w...
# 1   who had the best instagram photo of the week?!...
# 2   these #royalrumble crashers were ruthless!  ht...
# 3   an all mighty moment in the 2023 men's #royalr...
# 4                                    outta nowhere! 😲
# 5   thanks for stopping by the wwe performance cen...
# 6   the tribal chief is unfazed 🤣  @wweromanreigns...
# 7   it was great to have @dkelce1 come out and vis...
# 8   attention @nhlflyers fans!  @grittynhl has the...
# 9   the #dustyclassic continues next week on #wwen...
# 10  available now on @wweshop!  get these all-new ...
# 11  take a look at @tiffstrattonwwe's eventful day...
# 12  enjoy a cold one on #nationalmilkday just like...
# 13                            happy #nationalmilkday!
# 14  can big body javi upset @joegacy tomorrow nigh...
# 15  thanks for joining us on #wwethebump, @miayim!...
# 16  live, laugh, love! r-truth & the judgment day ...
# 17  they weren't supposed to be in the #royalrumbl...
# 18                                                  👀
# 19                          message sent.  #smackdown
# 20  icymi:   watch r-truth's lovely tribute to the...
# 21                                 say it to my chest
# 22  the judgment day, the awesome truth and #diy ....
# 23  the road to #vengeanceday got started in a big...
# 24  intercontinental champion @gunther_aut returns...
# 25  next week on #wwenxt   🤔 a battle royal with a...
# 26  wwe on a&e is back!  beginning sunday, feb. 25...
# 27  wwe superstar sunday on @aetv is officially ba...
# 28  step back into the ring with @wwe superstar su...
# 29  can @dmcintyrewwe become a 2-time #royalrumble...
# 30               can someone please change my diaper?
# 31  how it started ➡️ how it ended  oba femi has a...
# 32  today at 1pm et:  🔥 no. 1 contender for the ww...
# 33                    lincoln, ne this friday❗️  @wwe
# 34  today at 1pm et; reply to the tweet below and ...
# 35                    happy birthday to @taminasnuka!
# 36                               what a 2023 for wwe!
# 37  exclusive: new nxt north american champion oba...
# 38  exclusive: @tonydangelowwe, @stacks_wwe, and @...
# 39  exclusive: even though she may have come up sh...
#
#                                                tokens  \
# 0   [if, ya, smell, ....., @, therock, has, come, ...
# 1   [who, had, the, best, instagram, photo, of, th...
# 2   [these, #, royalrumble, crashers, were, ruthle...
# 3   [an, all, mighty, moment, in, the, 2023, men, ...
# 4                              [outta, nowhere, !, 😲]
# 5   [thanks, for, stopping, by, the, wwe, performa...
# 6   [the, tribal, chief, is, unfazed, 🤣, @, wwerom...
# 7   [it, was, great, to, have, @, dkelce1, come, o...
# 8   [attention, @, nhlflyers, fans, !, @, grittynh...
# 9   [the, #, dustyclassic, continues, next, week, ...
# 10  [available, now, on, @, wweshop, !, get, these...
# 11  [take, a, look, at, @, tiffstrattonwwe, 's, ev...
# 12  [enjoy, a, cold, one, on, #, nationalmilkday, ...
# 13                     [happy, #, nationalmilkday, !]
# 14  [can, big, body, javi, upset, @, joegacy, tomo...
# 15  [thanks, for, joining, us, on, #, wwethebump, ...
# 16  [live, ,, laugh, ,, love, !, r-truth, &, the, ...
# 17  [they, were, n't, supposed, to, be, in, the, #...
# 18                                                [👀]
# 19                   [message, sent, ., #, smackdown]
# 20  [icymi, :, watch, r-truth, 's, lovely, tribute...
# 21                           [say, it, to, my, chest]
# 22  [the, judgment, day, ,, the, awesome, truth, a...
# 23  [the, road, to, #, vengeanceday, got, started,...
# 24  [intercontinental, champion, @, gunther_aut, r...
# 25  [next, week, on, #, wwenxt, 🤔, a, battle, roya...
# 26  [wwe, on, a, &, e, is, back, !, beginning, sun...
# 27  [wwe, superstar, sunday, on, @, aetv, is, offi...
# 28  [step, back, into, the, ring, with, @, wwe, su...
# 29  [can, @, dmcintyrewwe, become, a, 2-time, #, r...
# 30      [can, someone, please, change, my, diaper, ?]
# 31  [how, it, started, ➡️, how, it, ended, oba, fe...
# 32  [today, at, 1pm, et, :, 🔥, no, ., 1, contender...
# 33           [lincoln, ,, ne, this, friday❗️, @, wwe]
# 34  [today, at, 1pm, et, ;, reply, to, the, tweet,...
# 35           [happy, birthday, to, @, taminasnuka, !]
# 36                       [what, a, 2023, for, wwe, !]
# 37  [exclusive, :, new, nxt, north, american, cham...
# 38  [exclusive, :, @, tonydangelowwe, ,, @, stacks...
# 39  [exclusive, :, even, though, she, may, have, c...
#
#                                          cleaned_text  \
# 0            ifyasmell.....therockhascomebacktowweraw
# 1   whohadthebestinstagramphotooftheweekhttps//www...
# 2   theseroyalrumblecrasherswereruthlesshttps//tub...
# 3     anallmightymomentinthe2023men'sroyalrumblematch
# 4                                       outtanowhere😲
# 5   thanksforstoppingbythewweperformancecenterdkelce1
# 6   thetribalchiefisunfazed🤣wweromanreignsheymanhu...
# 7   itwasgreattohavedkelce1comeoutandvisitthewwepe...
# 8   attentionnhlflyersfansgrittynhlhasthewwegolden...
# 9   thedustyclassiccontinuesnextweekonwwenxtwithth...
# 10  availablenowonwweshopgettheseall-newshirtsfeat...
# 11  takealookattiffstrattonwwe'seventfuldayasfallo...
# 12  enjoyacoldoneonnationalmilkdayjustliketherockr...
# 13                               happynationalmilkday
# 14  canbigbodyjaviupsetjoegacytomorrownightonnxtle...
# 15  thanksforjoiningusonwwethebumpmiayim2024isshap...
# 16  livelaughlover-truththejudgmentdayhave2newtees...
# 17  theyweren'tsupposedtobeintheroyalrumblematchwh...
# 18                                                  👀
# 19                               messagesentsmackdown
# 20  icymiwatchr-truth'slovelytributetothejudgmentd...
# 21                                     sayittomychest
# 22  thejudgmentdaytheawesometruthanddiy...ohmythis...
# 23  theroadtovengeancedaygotstartedinabigwaylastni...
# 24  intercontinentalchampiongunther_autreturnstoww...
# 25  nextweekonwwenxt🤔abattleroyalwithatwistwilldet...
# 26  wweonaeisbackbeginningsundayfeb.25wweandaetvpr...
# 27  wwesuperstarsundayonaetvisofficiallybackrelive...
# 28  stepbackintotheringwithwwesuperstarsundayall-n...
# 29  candmcintyrewwebecomea2-timeroyalrumblematchwi...
# 30                     cansomeonepleasechangemydiaper
# 31   howitstarted➡️howitendedobafemihasarrived👊wwenxt
# 32  todayat1pmet🔥no1contenderforthewweworldheavywe...
# 33                           lincolnnethisfriday❗️wwe
# 34  todayat1pmetreplytothetweetbelowandimayanswery...
# 35                         happybirthdaytotaminasnuka
# 36                                    whata2023forwwe
# 37  exclusivenewnxtnorthamericanchampionobafemiput...
# 38  exclusivetonydangelowwestacks_wweandadrianariz...
# 39  exclusiveeventhoughshemayhavecomeupshortgigido...
#
#                                         filtered_text  \
# 0       ya smell ..... @ therock come back # wweraw !
# 1   best instagram photo week ? ! https : //www.ww...
# 2   # royalrumble crashers ruthless ! https : //tu...
# 3     mighty moment 2023 men 's # royalrumble match !
# 4                                   outta nowhere ! 😲
# 5   thanks stopping wwe performance center @ dkelc...
# 6   tribal chief unfazed 🤣 @ wweromanreigns @ heym...
# 7   great @ dkelce1 come visit wwe performance cen...
# 8   attention @ nhlflyers fans ! @ grittynhl # wwe...
# 9   # dustyclassic continues next week # wwenxt tw...
# 10  available @ wweshop ! get all-new shirts featu...
# 11  take look @ tiffstrattonwwe 's eventful day @ ...
# 12  enjoy cold one # nationalmilkday like @ theroc...
# 13                          happy # nationalmilkday !
# 14  big body javi upset @ joegacy tomorrow night #...
# 15  thanks joining us # wwethebump , @ miayim ! 20...
# 16  live , laugh , love ! r-truth & judgment day 2...
# 17  n't supposed # royalrumble match ! happens wwe...
# 18                                                  👀
# 19                         message sent . # smackdown
# 20  icymi : watch r-truth 's lovely tribute judgme...
# 21                                          say chest
# 22  judgment day , awesome truth # diy ... oh ! mo...
# 23  road # vengeanceday got started big way last n...
# 24  intercontinental champion @ gunther_aut return...
# 25  next week # wwenxt 🤔 battle royal twist determ...
# 26  wwe & e back ! beginning sunday , feb. 25 , @ ...
# 27  wwe superstar sunday @ aetv officially back ! ...
# 28  step back ring @ wwe superstar sunday ! all-ne...
# 29  @ dmcintyrewwe become 2-time # royalrumble mat...
# 30                     someone please change diaper ?
# 31       started ➡️ ended oba femi arrived 👊 # wwenxt
# 32  today 1pm et : 🔥 . 1 contender wwe world heavy...
# 33                        lincoln , ne friday❗️ @ wwe
# 34  today 1pm et ; reply tweet may answer question...
# 35                     happy birthday @ taminasnuka !
# 36                                         2023 wwe !
# 37  exclusive : new nxt north american champion ob...
# 38  exclusive : @ tonydangelowwe , @ stacks_wwe , ...
# 39  exclusive : even though may come short , @ gig...
#
#                                          stemmed_Text  \
# 0   if ya smell ..... @ therock ha come back to # ...
# 1   who had the best instagram photo of the week ?...
# 2   these # royalrumbl crasher were ruthless ! htt...
# 3   an all mighti moment in the 2023 men 's # roya...
# 4                                    outta nowher ! 😲
# 5   thank for stop by the wwe perform center @ dke...
# 6   the tribal chief is unfaz 🤣 @ wweromanreign @ ...
# 7   it wa great to have @ dkelce1 come out and vis...
# 8   attent @ nhlflyer fan ! @ grittynhl ha the # w...
# 9   the # dustyclass continu next week on # wwenxt...
# 10  avail now on @ wweshop ! get these all-new shi...
# 11  take a look at @ tiffstrattonww 's event day a...
# 12  enjoy a cold one on # nationalmilkday just lik...
# 13                          happi # nationalmilkday !
# 14  can big bodi javi upset @ joegaci tomorrow nig...
# 15  thank for join us on # wwethebump , @ miayim !...
# 16  live , laugh , love ! r-truth & the judgment d...
# 17  they were n't suppos to be in the # royalrumbl...
# 18                                                  👀
# 19                          messag sent . # smackdown
# 20  icymi : watch r-truth 's love tribut to the ju...
# 21                                 say it to my chest
# 22  the judgment day , the awesom truth and # diy ...
# 23  the road to # vengeanceday got start in a big ...
# 24  intercontinent champion @ gunther_aut return t...
# 25  next week on # wwenxt 🤔 a battl royal with a t...
# 26  wwe on a & e is back ! begin sunday , feb. 25 ...
# 27  wwe superstar sunday on @ aetv is offici back ...
# 28  step back into the ring with @ wwe superstar s...
# 29  can @ dmcintyreww becom a 2-time # royalrumbl ...
# 30                 can someon pleas chang my diaper ?
# 31  how it start ➡️ how it end oba femi ha arriv 👊...
# 32  today at 1pm et : 🔥 no . 1 contend for the wwe...
# 33                    lincoln , ne thi friday❗️ @ wwe
# 34  today at 1pm et ; repli to the tweet below and...
# 35                  happi birthday to @ taminasnuka !
# 36                              what a 2023 for wwe !
# 37  exclus : new nxt north american champion oba f...
# 38  exclus : @ tonydangeloww , @ stacks_ww , and @...
# 39  exclus : even though she may have come up shor...
#
#                                       lemmatized_text  simple_count  \
# 0   if ya smell ..... @ therock ha come back to # ...            12
# 1   who had the best instagram photo of the week ?...            15
# 2   these # royalrumble crasher were ruthless ! ht...            10
# 3   an all mighty moment in the 2023 men 's # roya...            13
# 4                                   outta nowhere ! 😲             4
# 5   thanks for stopping by the wwe performance cen...            11
# 6   the tribal chief is unfazed 🤣 @ wweromanreigns...            10
# 7   it wa great to have @ dkelce1 come out and vis...            16
# 8   attention @ nhlflyers fan ! @ grittynhl ha the...            22
# 9   the # dustyclassic continues next week on # ww...            29
# 10  available now on @ wweshop ! get these all-new...            24
# 11  take a look at @ tiffstrattonwwe 's eventful d...            17
# 12  enjoy a cold one on # nationalmilkday just lik...            15
# 13                          happy # nationalmilkday !             4
# 14  can big body javi upset @ joegacy tomorrow nig...            15
# 15  thanks for joining u on # wwethebump , @ miayi...            31
# 16  live , laugh , love ! r-truth & the judgment d...            25
# 17  they were n't supposed to be in the # royalrum...            30
# 18                                                  👀             1
# 19                         message sent . # smackdown             5
# 20  icymi : watch r-truth 's lovely tribute to the...            23
# 21                                 say it to my chest             5
# 22  the judgment day , the awesome truth and # diy...            22
# 23  the road to # vengeanceday got started in a bi...            36
# 24  intercontinental champion @ gunther_aut return...            10
# 25  next week on # wwenxt 🤔 a battle royal with a ...            41
# 26  wwe on a & e is back ! beginning sunday , feb....            41
# 27  wwe superstar sunday on @ aetv is officially b...            32
# 28  step back into the ring with @ wwe superstar s...            31
# 29  can @ dmcintyrewwe become a 2-time # royalrumb...            19
# 30              can someone please change my diaper ?             7
# 31  how it started ➡️ how it ended oba femi ha arr...            13
# 32  today at 1pm et : 🔥 no . 1 contender for the w...            39
# 33                   lincoln , ne this friday❗️ @ wwe             7
# 34  today at 1pm et ; reply to the tweet below and...            25
# 35                  happy birthday to @ taminasnuka !             6
# 36                              what a 2023 for wwe !             6
# 37  exclusive : new nxt north american champion ob...            21
# 38  exclusive : @ tonydangelowwe , @ stacks_wwe , ...            28
# 39  exclusive : even though she may have come up s...            30
#
#     complex_count
# 0               1
# 1               1
# 2               2
# 3               0
# 4               0
# 5               0
# 6               0
# 7               1
# 8               2
# 9               1
# 10              2
# 11              1
# 12              0
# 13              0
# 14              1
# 15              2
# 16              2
# 17              3
# 18              0
# 19              0
# 20              1
# 21              0
# 22              0
# 23              1
# 24              1
# 25              1
# 26              4
# 27              6
# 28              3
# 29              1
# 30              0
# 31              1
# 32              0
# 33              0
# 34              0
# 35              0
# 36              0
# 37              1
# 38              0
# 39              2

# %% [markdown]
# ### 7. Translation

# %%
# Task 7: Translation
# translator = google_translator()
df['translated_text'] = df['lowercased_text'].apply(lambda x: GoogleTranslator(source='auto', target='es').translate(x))  # Translate to Spanish
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text  \
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲
#
#                                               tokens  \
# 0  [if, ya, smell, ....., @, therock, has, come, ...
# 1  [who, had, the, best, instagram, photo, of, th...
# 2  [these, #, royalrumble, crashers, were, ruthle...
# 3  [an, all, mighty, moment, in, the, 2023, men, ...
# 4                             [outta, nowhere, !, 😲]
#
#                                         cleaned_text  \
# 0           ifyasmell.....therockhascomebacktowweraw
# 1  whohadthebestinstagramphotooftheweekhttps//www...
# 2  theseroyalrumblecrasherswereruthlesshttps//tub...
# 3    anallmightymomentinthe2023men'sroyalrumblematch
# 4                                      outtanowhere😲
#
#                                        filtered_text  \
# 0      ya smell ..... @ therock come back # wweraw !
# 1  best instagram photo week ? ! https : //www.ww...
# 2  # royalrumble crashers ruthless ! https : //tu...
# 3    mighty moment 2023 men 's # royalrumble match !
# 4                                  outta nowhere ! 😲
#
#                                         stemmed_Text  \
# 0  if ya smell ..... @ therock ha come back to # ...
# 1  who had the best instagram photo of the week ?...
# 2  these # royalrumbl crasher were ruthless ! htt...
# 3  an all mighti moment in the 2023 men 's # roya...
# 4                                   outta nowher ! 😲
#
#                                      lemmatized_text  simple_count  \
# 0  if ya smell ..... @ therock ha come back to # ...            12
# 1  who had the best instagram photo of the week ?...            15
# 2  these # royalrumble crasher were ruthless ! ht...            10
# 3  an all mighty moment in the 2023 men 's # roya...            13
# 4                                  outta nowhere ! 😲             4
#
#    complex_count                                    translated_text
# 0              1        Si hueles... ¡@therock ha vuelto a #wweraw!
# 1              1  ¿Quién tuvo la mejor foto de Instagram de la s...
# 2              2  ¡Estos intrusos del #royalrumble fueron despia...
# 3              0  ¡Un momento todopoderoso en el partido #RoyalR...
# 4              0                                     ¡de la nada! 😲

# %% [markdown]
# ### 8. Emoji to text

# %%
# Task 8: Emoji to Text
df['emoji_to_text'] = df['text'].apply(lambda x: emoji.demojize(x))
df.head()
# Out:
#                                                 text  \
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                                   Outta nowhere! 😲
#
#                                      lowercased_text  \
# 0  if ya smell.....  @therock has come back to #w...
# 1  who had the best instagram photo of the week?!...
# 2  these #royalrumble crashers were ruthless!  ht...
# 3  an all mighty moment in the 2023 men's #royalr...
# 4                                   outta nowhere! 😲
#
#                                               tokens  \
# 0  [if, ya, smell, ....., @, therock, has, come, ...
# 1  [who, had, the, best, instagram, photo, of, th...
# 2  [these, #, royalrumble, crashers, were, ruthle...
# 3  [an, all, mighty, moment, in, the, 2023, men, ...
# 4                             [outta, nowhere, !, 😲]
#
#                                         cleaned_text  \
# 0           ifyasmell.....therockhascomebacktowweraw
# 1  whohadthebestinstagramphotooftheweekhttps//www...
# 2  theseroyalrumblecrasherswereruthlesshttps//tub...
# 3    anallmightymomentinthe2023men'sroyalrumblematch
# 4                                      outtanowhere😲
#
#                                        filtered_text  \
# 0      ya smell ..... @ therock come back # wweraw !
# 1  best instagram photo week ? ! https : //www.ww...
# 2  # royalrumble crashers ruthless ! https : //tu...
# 3    mighty moment 2023 men 's # royalrumble match !
# 4                                  outta nowhere ! 😲
#
#                                         stemmed_Text  \
# 0  if ya smell ..... @ therock ha come back to # ...
# 1  who had the best instagram photo of the week ?...
# 2  these # royalrumbl crasher were ruthless ! htt...
# 3  an all mighti moment in the 2023 men 's # roya...
# 4                                   outta nowher ! 😲
#
#                                      lemmatized_text  simple_count  \
# 0  if ya smell ..... @ therock ha come back to # ...            12
# 1  who had the best instagram photo of the week ?...            15
# 2  these # royalrumble crasher were ruthless ! ht...            10
# 3  an all mighty moment in the 2023 men 's # roya...            13
# 4                                  outta nowhere ! 😲             4
#
#    complex_count                                    translated_text  \
# 0              1        Si hueles... ¡@therock ha vuelto a #wweraw!
# 1              1  ¿Quién tuvo la mejor foto de Instagram de la s...
# 2              2  ¡Estos intrusos del #royalrumble fueron despia...
# 3              0  ¡Un momento todopoderoso en el partido #RoyalR...
# 4              0                                     ¡de la nada! 😲
#
#                                        emoji_to_text
# 0  IF YA SMELL.....  @TheRock has come back to #W...
# 1  Who had the best Instagram photo of the week?!...
# 2  These #RoyalRumble crashers were RUTHLESS!  ht...
# 3  An All Mighty moment in the 2023 Men's #RoyalR...
# 4                   Outta nowhere! :astonished_face:

# %% [markdown]
# ## Perform the following task without using inbuilt Python Libraries (The last two task (Translation and Emoji) are not possible without libraies):

# %%
import re
import string

# Sample text data
text_data = data.head()['text']

# Task 1: Lowercasing
lowercased_texts = [text.lower() for text in text_data]

# Task 2: Tokenization
tokenized_texts = [re.findall(r'\b\w+\b', text) for text in text_data]

# Task 3: Punctuation Mark Removal
cleaned_texts = [''.join(char for char in text if char not in string.punctuation) for text in text_data]

# Task 4: Stop Word Removal
stop_words = set(["a", "an", "the", "is", "from", "this"])
filtered_texts = [' '.join(word for word in text.split() if word.lower() not in stop_words) for text in text_data]

# Task 5: Stemming
def simple_stemming(text):
    return ' '.join(word[:4] if len(word) > 4 else word for word in text.split())

stemmed_texts = [simple_stemming(text) for text in text_data]

# Task 6: Lemmatization
def simple_lemmatization(text):
    return ' '.join(word[:-2] if word.endswith("es") else word for word in text.split())

lemmatized_texts = [simple_lemmatization(text) for text in text_data]

# Display results
for i in range(len(text_data)):
    print(f"\nOriginal Text: {text_data[i]}")
    print(f"Lowercased Text: {lowercased_texts[i]}")
    print(f"Tokenized Text: {tokenized_texts[i]}")
    print(f"Cleaned Text: {cleaned_texts[i]}")
    print(f"Filtered Text: {filtered_texts[i]}")
    print(f"Stemmed Text: {stemmed_texts[i]}")
    print(f"Lemmatized Text: {lemmatized_texts[i]}")
# Out:
# Original Text: IF YA SMELL.....  @TheRock has come back to #WWERaw!
# Lowercased Text: if ya smell.....  @therock has come back to #wweraw!
# Tokenized Text: ['IF', 'YA', 'SMELL', 'TheRock', 'has', 'come', 'back', 'to', 'WWERaw']
# Cleaned Text: IF YA SMELL  TheRock has come back to WWERaw
# Filtered Text: IF YA SMELL..... @TheRock has come back to #WWERaw!
# Stemmed Text: IF YA SMEL @The has come back to #WWE
# Lemmatized Text: IF YA SMELL..... @TheRock has come back to #WWERaw!
#
# Original Text: Who had the best Instagram photo of the week?!  https://www.wwe.com/gallery/the-25-best-instagram-photos-of-the-week-january-7-2024#fid-40650941
# Lowercased Text: who had the best instagram photo of the week?!  https://www.wwe.com/gallery/the-25-best-instagram-photos-of-the-week-january-7-2024#fid-40650941
# Tokenized Text: ['Who', 'had', 'the', 'best', 'Instagram', 'photo', 'of', 'the', 'week', 'https', 'www', 'wwe', 'com', 'gallery', 'the', '25', 'best', 'instagram', 'photos', 'of', 'the', 'week', 'january', '7', '2024', 'fid', '40650941']
# Cleaned Text: Who had the best Instagram photo of the week  httpswwwwwecomgallerythe25bestinstagramphotosoftheweekjanuary72024fid40650941
# Filtered Text: Who had best Instagram photo of week?! https://www.wwe.com/gallery/the-25-best-instagram-photos-of-the-week-january-7-2024#fid-40650941
# Stemmed Text: Who had the best Inst phot of the week http
# Lemmatized Text: Who had the best Instagram photo of the week?! https://www.wwe.com/gallery/the-25-best-instagram-photos-of-the-week-january-7-2024#fid-40650941
#
# Original Text: These #RoyalRumble crashers were RUTHLESS!  https://tube.mint.lgbt/VV5fxHfxCE4?si=naZCLWedRVreRISE
# Lowercased Text: these #royalrumble crashers were ruthless!  https://tube.mint.lgbt/vv5fxhfxce4?si=nazclwedrvrerise
# Tokenized Text: ['These', 'RoyalRumble', 'crashers', 'were', 'RUTHLESS', 'https', 'tube', 'mint', 'lgbt', 'VV5fxHfxCE4', 'si', 'naZCLWedRVreRISE']
# Cleaned Text: These RoyalRumble crashers were RUTHLESS  httpstubemintlgbtVV5fxHfxCE4sinaZCLWedRVreRISE
# Filtered Text: These #RoyalRumble crashers were RUTHLESS! https://tube.mint.lgbt/VV5fxHfxCE4?si=naZCLWedRVreRISE
# Stemmed Text: Thes #Roy cras were RUTH http
# Lemmatized Text: These #RoyalRumble crashers were RUTHLESS! https://tube.mint.lgbt/VV5fxHfxCE4?si=naZCLWedRVreRISE
#
# Original Text: An All Mighty moment in the 2023 Men's #RoyalRumble Match!
# Lowercased Text: an all mighty moment in the 2023 men's #royalrumble match!
# Tokenized Text: ['An', 'All', 'Mighty', 'moment', 'in', 'the', '2023', 'Men', 's', 'RoyalRumble', 'Match']
# Cleaned Text: An All Mighty moment in the 2023 Mens RoyalRumble Match
# Filtered Text: All Mighty moment in 2023 Men's #RoyalRumble Match!
# Stemmed Text: An All Migh mome in the 2023 Men' #Roy Matc
# Lemmatized Text: An All Mighty moment in the 2023 Men's #RoyalRumble Match!
#
# Original Text: Outta nowhere! 😲
# Lowercased Text: outta nowhere! 😲
# Tokenized Text: ['Outta', 'nowhere']
# Cleaned Text: Outta nowhere 😲
# Filtered Text: Outta nowhere! 😲
# Stemmed Text: Outt nowh 😲
# Lemmatized Text: Outta nowhere! 😲

# %%
# !pip install inflect
# Out:
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (7.4.0)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect) (4.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from typeguard>=4.0.1->inflect) (4.12.2)

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk import pos_tag

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')

sentence = "The cat sat on the mat."
tokens = word_tokenize(sentence)
tagged_tokens = pos_tag(tokens)
print("POS Tagging:")
for token, tag in tagged_tokens:
    print(f'{token} -> {tag}')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# POS Tagging:
# The -> DT
# cat -> NN
# sat -> VBD
# on -> IN
# the -> DT
# mat -> NN
# . -> .

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk import pos_tag

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
for tokens in tokenized_texts:
  tagged_tokens = pos_tag(tokens)
  print("POS Tagging:")
  for token, tag in tagged_tokens:
      print(f'{token} -> {tag}')
  print("\nWordNet Exploration:")
  word = tokens[0]

  synsets = wn.synsets(word)
  print(f"\nSynsets of '{word}':")
  for synset in synsets:
      print(f"- {synset.name()}: {synset.definition()}")
  print(f"\nLemmas of '{word}':")
  for synset in synsets:
      lemmas = synset.lemmas()
      for lemma in lemmas:
          print(f"- {lemma.name()}")
  print(f"\nHypernyms of '{word}':")
  for synset in synsets:
      hypernyms = synset.hypernyms()
      for hypernym in hypernyms:
          print(f"- {synset.name()} -> {hypernym.name()}")
  print(f"\nHyponyms of '{word}':")
  for synset in synsets:
      hyponyms = synset.hyponyms()
      for hyponym in hyponyms:
          print(f"- {synset.name()} -> {hyponym.name()}")
  print(f"\nExample sentences for '{word}':")
  for synset in synsets:
      examples = synset.examples()
      for example in examples:
          print(f"- {synset.name()}: {example}")
# Out:
# POS Tagging:
# IF -> NNP
# YA -> NNP
# SMELL -> NNP
# TheRock -> NNP
# has -> VBZ
# come -> VBN
# back -> RB
# to -> TO
# WWERaw -> NNP
#
# WordNet Exploration:
#
# Synsets of 'IF':
#
# Lemmas of 'IF':
#
# Hypernyms of 'IF':
#
# Hyponyms of 'IF':
#
# Example sentences for 'IF':
# POS Tagging:
# Who -> WP
# had -> VBD
# the -> DT
# best -> JJS
# Instagram -> NNP
# photo -> NN
# of -> IN
# the -> DT
# week -> NN
# https -> NN
# www -> NN
# wwe -> NN
# com -> NN
# gallery -> VBD
# the -> DT
# 25 -> CD
# best -> JJS
# instagram -> NN
# photos -> NN
# of -> IN
# the -> DT
# week -> NN
# january -> JJ
# 7 -> CD
# 2024 -> CD
# fid -> NN
# 40650941 -> CD
#
# WordNet Exploration:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Synsets of 'Who':
# - world_health_organization.n.01: a United Nations agency to coordinate international health activities and to help governments improve health services
#
# Lemmas of 'Who':
# - World_Health_Organization
# - WHO
#
# Hypernyms of 'Who':
# - world_health_organization.n.01 -> united_nations_agency.n.01
#
# Hyponyms of 'Who':
#
# Example sentences for 'Who':
# POS Tagging:
# These -> DT
# RoyalRumble -> JJ
# crashers -> NNS
# were -> VBD
# RUTHLESS -> NNP
# https -> NN
# tube -> NN
# mint -> NN
# lgbt -> NN
# VV5fxHfxCE4 -> NNP
# si -> NN
# naZCLWedRVreRISE -> NN
#
# WordNet Exploration:
#
# Synsets of 'These':
#
# Lemmas of 'These':
#
# Hypernyms of 'These':
#
# Hyponyms of 'These':
#
# Example sentences for 'These':
# POS Tagging:
# An -> DT
# All -> DT
# Mighty -> NNP
# moment -> NN
# in -> IN
# the -> DT
# 2023 -> CD
# Men -> NNP
# s -> VBD
# RoyalRumble -> JJ
# Match -> NN
#
# WordNet Exploration:
#
# Synsets of 'An':
# - associate_in_nursing.n.01: an associate degree in nursing
#
# Lemmas of 'An':
# - Associate_in_Nursing
# - AN
#
# Hypernyms of 'An':
# - associate_in_nursing.n.01 -> associate_degree.n.01
#
# Hyponyms of 'An':
#
# Example sentences for 'An':
# POS Tagging:
# Outta -> NNP
# nowhere -> RB
#
# WordNet Exploration:
#
# Synsets of 'Outta':
#
# Lemmas of 'Outta':
#
# Hypernyms of 'Outta':
#
# Hyponyms of 'Outta':
#
# Example sentences for 'Outta':

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from time import time

nltk.download('treebank')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

pos_full_form = {
    'CC': 'Coordinating conjunction', 'CD': 'Cardinal digit', 'DT': 'Determiner',
    'EX': 'Existential there', 'FW': 'Foreign word', 'IN': 'Preposition/subordinating conjunction',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'LS': 'List item marker', 'MD': 'Modal', 'NN': 'Noun, singular or mass', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural', 'PDT': 'Predeterminer',
    'POS': 'Possessive ending', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative', 'RP': 'Particle',
    'TO': 'To', 'UH': 'Interjection', 'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund or present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun', 'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

def wordnet_pos_code(tag):
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('V'):
        return wn.VERB
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    else:
        return None

tokenization = tokenized_texts

total_treebank_time = 0
total_wordnet_time = 0
total_precision = 0
total_sentences = len(tokenization)

def get_pos_full_form(tag):
    return pos_full_form.get(tag, "Unknown")

for tokens in tokenization:
    print(f"\nProcessing sentence: {' '.join(tokens)}")

    # Treebank
    start_treebank = time()
    treebank_tags = pos_tag(tokens)
    end_treebank = time()

    print("Treebank POS tagging results:")
    for token, tag in treebank_tags:
        print(f'{token} -> {tag} ({get_pos_full_form(tag)})')

    # WordNet
    start_wordnet = time()
    wordnet_tags = []
    for token, tag in treebank_tags:
        wn_tag = wordnet_pos_code(tag)
        if wn_tag:
            synsets = wn.synsets(token, wn_tag)
            if synsets:
                wn_tagged = synsets[0].pos()
            else:
                wn_tagged = "unknown"
        else:
            wn_tagged = "unknown"
        wordnet_tags.append((token, wn_tagged))
    end_wordnet = time()

    print("\nWordNet-based tagging results:")
    for token, tag in wordnet_tags:
        print(f'{token} -> {tag}')

    treebank_time = end_treebank - start_treebank
    wordnet_time = end_wordnet - start_wordnet
    total_treebank_time += treebank_time
    total_wordnet_time += wordnet_time

    correct_matches = sum(1 for t1, t2 in zip(treebank_tags, wordnet_tags) if t1[1].startswith(t2[1].upper()))
    precision = correct_matches / len(treebank_tags)
    total_precision += precision

avg_precision = total_precision / total_sentences
avg_treebank_time = total_treebank_time / total_sentences
avg_wordnet_time = total_wordnet_time / total_sentences
print(f"\nOverall average time for Treebank POS tagging: {avg_treebank_time:.6f} seconds")
print(f"Overall average time for WordNet-based tagging: {avg_wordnet_time:.6f} seconds")
print(f"Overall precision (accuracy): {avg_precision:.2f}")
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# Processing sentence: IF YA SMELL TheRock has come back to WWERaw
# Treebank POS tagging results:
# IF -> NNP (Proper noun, singular)
# YA -> NNP (Proper noun, singular)
# SMELL -> NNP (Proper noun, singular)
# TheRock -> NNP (Proper noun, singular)
# has -> VBZ (Verb, 3rd person singular present)
# come -> VBN (Verb, past participle)
# back -> RB (Adverb)
# to -> TO (To)
# WWERaw -> NNP (Proper noun, singular)
#
# WordNet-based tagging results:
# IF -> unknown
# YA -> unknown
# SMELL -> n
# TheRock -> unknown
# has -> v
# come -> v
# back -> r
# to -> unknown
# WWERaw -> unknown
#
# Processing sentence: Who had the best Instagram photo of the week https www wwe com gallery the 25 best instagram photos of the week january 7 2024 fid 40650941
# Treebank POS tagging results:
# Who -> WP (Wh-pronoun)
# had -> VBD (Verb, past tense)
# the -> DT (Determiner)
# best -> JJS (Adjective, superlative)
# Instagram -> NNP (Proper noun, singular)
# photo -> NN (Noun, singular or mass)
# of -> IN (Preposition/subordinating conjunction)
# the -> DT (Determiner)
# week -> NN (Noun, singular or mass)
# https -> NN (Noun, singular or mass)
# www -> NN (Noun, singular or mass)
# wwe -> NN (Noun, singular or mass)
# com -> NN (Noun, singular or mass)
# gallery -> VBD (Verb, past tense)
# the -> DT (Determiner)
# 25 -> CD (Cardinal digit)
# best -> JJS (Adjective, superlative)
# instagram -> NN (Noun, singular or mass)
# photos -> NN (Noun, singular or mass)
# of -> IN (Preposition/subordinating conjunction)
# the -> DT (Determiner)
# week -> NN (Noun, singular or mass)
# january -> JJ (Adjective)
# 7 -> CD (Cardinal digit)
# 2024 -> CD (Cardinal digit)
# fid -> NN (Noun, singular or mass)
# 40650941 -> CD (Cardinal digit)
#
# WordNet-based tagging results:
# Who -> unknown
# had -> v
# the -> unknown
# best -> a
# Instagram -> unknown
# photo -> n
# of -> unknown
# the -> unknown
# week -> n
# https -> n
# www -> n
# wwe -> unknown
# com -> unknown
# gallery -> unknown
# the -> unknown
# 25 -> unknown
# best -> a
# instagram -> unknown
# photos -> n
# of -> unknown
# the -> unknown
# week -> n
# january -> unknown
# 7 -> unknown
# 2024 -> unknown
# fid -> unknown
# 40650941 -> unknown
#
# Processing sentence: These RoyalRumble crashers were RUTHLESS https tube mint lgbt VV5fxHfxCE4 si naZCLWedRVreRISE
# Treebank POS tagging results:
# These -> DT (Determiner)
# RoyalRumble -> JJ (Adjective)
# crashers -> NNS (Noun, plural)
# were -> VBD (Verb, past tense)
# RUTHLESS -> NNP (Proper noun, singular)
# https -> NN (Noun, singular or mass)
# tube -> NN (Noun, singular or mass)
# mint -> NN (Noun, singular or mass)
# lgbt -> NN (Noun, singular or mass)
# VV5fxHfxCE4 -> NNP (Proper noun, singular)
# si -> NN (Noun, singular or mass)
# naZCLWedRVreRISE -> NN (Noun, singular or mass)
#
# WordNet-based tagging results:
# These -> unknown
# RoyalRumble -> unknown
# crashers -> n
# were -> v
# RUTHLESS -> unknown
# https -> n
# tube -> n
# mint -> n
# lgbt -> unknown
# VV5fxHfxCE4 -> unknown
# si -> n
# naZCLWedRVreRISE -> unknown
#
# Processing sentence: An All Mighty moment in the 2023 Men s RoyalRumble Match
# Treebank POS tagging results:
# An -> DT (Determiner)
# All -> DT (Determiner)
# Mighty -> NNP (Proper noun, singular)
# moment -> NN (Noun, singular or mass)
# in -> IN (Preposition/subordinating conjunction)
# the -> DT (Determiner)
# 2023 -> CD (Cardinal digit)
# Men -> NNP (Proper noun, singular)
# s -> VBD (Verb, past tense)
# RoyalRumble -> JJ (Adjective)
# Match -> NN (Noun, singular or mass)
#
# WordNet-based tagging results:
# An -> unknown
# All -> unknown
# Mighty -> unknown
# moment -> n
# in -> unknown
# the -> unknown
# 2023 -> unknown
# Men -> n
# s -> unknown
# RoyalRumble -> unknown
# Match -> n
#
# Processing sentence: Outta nowhere
# Treebank POS tagging results:
# Outta -> NNP (Proper noun, singular)
# nowhere -> RB (Adverb)
#
# WordNet-based tagging results:
# Outta -> unknown
# nowhere -> r
#
# Overall average time for Treebank POS tagging: 0.002774 seconds
# Overall average time for WordNet-based tagging: 0.018394 seconds
# Overall precision (accuracy): 0.40
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import nltk
from nltk import pos_tag
from prettytable import PrettyTable
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')

tokenization = tokenized_texts
pos_column_headers = ['Noun', 'Verb', 'Adjective', 'Adverb', 'Determiner', 'Preposition', 'Pronoun', 'Conjunction', 'Modal']

def categorize_pos(tag):
    if tag in ['NN', 'NNS', 'NNP', 'NNPS']:
        return 'Noun'
    elif tag in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']:
        return 'Verb'
    elif tag in ['JJ', 'JJR', 'JJS']:
        return 'Adjective'
    elif tag in ['RB', 'RBR', 'RBS']:
        return 'Adverb'
    elif tag == 'DT':
        return 'Determiner'
    elif tag == 'IN':
        return 'Preposition'
    elif tag in ['PRP', 'PRP$']:
        return 'Pronoun'
    elif tag == 'CC':
        return 'Conjunction'
    elif tag == 'MD':
        return 'Modal'
    else:
        return None

table = PrettyTable(['Sentence'] + pos_column_headers)
for tokens in tokenization:
    tagged_tokens = pos_tag(tokens)
    pos_dict = {category: [] for category in pos_column_headers}
    for token, tag in tagged_tokens:
        category = categorize_pos(tag)
        if category:
            pos_dict[category].append(token)

    table.add_row([
        ' '.join(tokens),
        pos_dict['Noun'],
        pos_dict['Verb'],
        pos_dict['Adjective'],
        pos_dict['Adverb'],
        pos_dict['Determiner'],
        pos_dict['Preposition'],
        pos_dict['Pronoun'],
        pos_dict['Conjunction'],
        pos_dict['Modal']
    ])

print(table)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+--------------------+-----------------------------+-------------+------------------------------+--------------+---------+-------------+-------+
# |                                                                   Sentence                                                                  |                                                Noun                                                |        Verb        |          Adjective          |    Adverb   |          Determiner          | Preposition  | Pronoun | Conjunction | Modal |
# +---------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+--------------------+-----------------------------+-------------+------------------------------+--------------+---------+-------------+-------+
# |                                                 IF YA SMELL TheRock has come back to WWERaw                                                 |                             ['IF', 'YA', 'SMELL', 'TheRock', 'WWERaw']                             |  ['has', 'come']   |              []             |   ['back']  |              []              |      []      |    []   |      []     |   []  |
# | Who had the best Instagram photo of the week https www wwe com gallery the 25 best instagram photos of the week january 7 2024 fid 40650941 | ['Instagram', 'photo', 'week', 'https', 'www', 'wwe', 'com', 'instagram', 'photos', 'week', 'fid'] | ['had', 'gallery'] | ['best', 'best', 'january'] |      []     | ['the', 'the', 'the', 'the'] | ['of', 'of'] |    []   |      []     |   []  |
# |                        These RoyalRumble crashers were RUTHLESS https tube mint lgbt VV5fxHfxCE4 si naZCLWedRVreRISE                        | ['crashers', 'RUTHLESS', 'https', 'tube', 'mint', 'lgbt', 'VV5fxHfxCE4', 'si', 'naZCLWedRVreRISE'] |      ['were']      |       ['RoyalRumble']       |      []     |          ['These']           |      []      |    []   |      []     |   []  |
# |                                           An All Mighty moment in the 2023 Men s RoyalRumble Match                                          |                                ['Mighty', 'moment', 'Men', 'Match']                                |       ['s']        |       ['RoyalRumble']       |      []     |     ['An', 'All', 'the']     |    ['in']    |    []   |      []     |   []  |
# |                                                                Outta nowhere                                                                |                                             ['Outta']                                              |         []         |              []             | ['nowhere'] |              []              |      []      |    []   |      []     |   []  |
# +---------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+--------------------+-----------------------------+-------------+------------------------------+--------------+---------+-------------+-------+
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
